# %% [markdown]
# # Feature Engineering
#
# Applies engineered features and inspects the resulting dataset.

# %%
import pandas as pd

from src.services.feature_engineering import add_features

DATA_PATH = "../data/raw/campaign_data.csv"

df = pd.read_csv(DATA_PATH)
engineered = add_features(df)
engineered.head()

# %%
new_cols = [c for c in engineered.columns if c not in df.columns]
new_cols
